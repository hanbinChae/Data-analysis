# %%
import matplotlib.pyplot as plt
import numpy as np

a = np.arange(0,2,0.2)

plt.plot(a,a,'r--',a,a**2,'bo',a,a**3,'g-.')
plt.show()

# %%
a = np.arange(0,2,0.2)

plt.plot(a,a,'bo')
plt.plot(a,a**2,color='#e35f62',marker='*',linewidth=2)
plt.plot(a,a**3,color='springgreen',marker='^',linewidth=9) #3개의 선 동시에 그리기
# plt.grid(True) #격자 무늬 그리기
# plt.grid(True,axis='y') #y축만 그리기, default는 both
plt.grid(True,axis='y',color='red',alpha=0.5,linestyle='--') #스타일 주기
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks([0, 1, 2]) #x축에 눈금 표시
plt.yticks(np.arange(1, 6)) #y축에 눈금 표시

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.xticks(np.arange(0, 2, 0.2), labels=['Jan', '', 'Feb', '', 'Mar', '', 'May', '', 'June', '', 'July']) #x축 눈금 레이블 지정
plt.yticks(np.arange(0, 7), ('0', '1GB', '2GB', '3GB', '4GB', '5GB', '6GB')) #y축 눈금 레이블 지정
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, 'bo')
plt.plot(a, a**2, color='#e35f62', marker='*', linewidth=2)
plt.plot(a, a**3, color='springgreen', marker='^', markersize=9)
plt.grid(True, axis='y', color='gray', alpha=0.5, linestyle='--')
plt.tick_params(axis='both', direction='in', length=3, pad=6, labelsize=14)

plt.title('Sample graph',loc="left",pad=20) #타이틀 지정 loc = 위치, pad = 그래프와의 간격
title_font = {
    'fontsize':16,
    'fontweight':'bold'
}
plt.title("sample graph",fontdict=title_font, loc='right',pad=20)


plt.show()
